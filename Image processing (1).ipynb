# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
flower = mpimg.imread("C:/Users/ABHISHEK/Pictures/Screenshots/Screenshot 2023-08-01 193508.png")
flower
# Out:
# array([[[0.00784314, 0.00392157, 0.02352941, 1.        ],
#         [0.00784314, 0.00392157, 0.02352941, 1.        ],
#         [0.00784314, 0.00392157, 0.02352941, 1.        ],
#         ...,
#         [0.9411765 , 0.827451  , 0.36862746, 1.        ],
#         [0.9764706 , 0.87058824, 0.42745098, 1.        ],
#         [0.9411765 , 0.84705883, 0.4627451 , 1.        ]],
#
#        [[0.00784314, 0.00392157, 0.02352941, 1.        ],
#         [0.00784314, 0.00392157, 0.02352941, 1.        ],
#         [0.00784314, 0.00392157, 0.02352941, 1.        ],
#         ...,
#         [0.9529412 , 0.84705883, 0.39607844, 1.        ],
#         [0.9607843 , 0.85882354, 0.41568628, 1.        ],
#         [0.972549  , 0.8745098 , 0.47843137, 1.        ]],
#
#        [[0.00784314, 0.00392157, 0.02352941, 1.        ],
#         [0.00784314, 0.00392157, 0.02352941, 1.        ],
#         [0.00784314, 0.00392157, 0.02352941, 1.        ],
#         ...,
# ...

# %%
type(flower)
# Out:
# numpy.ndarray

# %%
flower.shape
# Out:
# (433, 462, 4)

# %%
wrath_of_flower = plt.imshow(flower)
plt.show()

# %%
from PIL import Image

# %%
img = Image.open("C:/Users/ABHISHEK/Pictures/Screenshots/Screenshot 2023-08-01 193508.png")
img_resized = img.resize((200,200))

# %%
img_resized
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200>

# %%
img_resized.save('king_flower_resized.png')

# %%
img_res = mpimg.imread('king_flower_resized.png')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
img_res.shape
# Out:
# (200, 200, 4)

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
img = cv2.imread("C:/Users/ABHISHEK/Pictures/Screenshots/Screenshot 2023-08-01 193508.png")
img
# Out:
# array([[[  6,   1,   2],
#         [  6,   1,   2],
#         [  6,   1,   2],
#         ...,
#         [ 94, 211, 240],
#         [109, 222, 249],
#         [118, 216, 240]],
#
#        [[  6,   1,   2],
#         [  6,   1,   2],
#         [  6,   1,   2],
#         ...,
#         [101, 216, 243],
#         [106, 219, 245],
#         [122, 223, 248]],
#
#        [[  6,   1,   2],
#         [  6,   1,   2],
#         [  6,   1,   2],
#         ...,
#         [134, 237, 255],
#         [117, 223, 247],
#         [121, 227, 250]],
#
#        ...,
#
#        [[  6,   1,   2],
#         [  6,   1,   2],
#         [  6,   1,   2],
#         ...,
#         [ 47,  18,  27],
#         [ 47,  18,  27],
#         [ 47,  18,  27]],
#
#        [[  6,   1,   2],
#         [  6,   1,   2],
#         [  6,   1,   2],
#         ...,
#         [ 47,  18,  27],
#         [ 47,  18,  27],
#         [ 47,  18,  27]],
#
#        [[  6,   1,   2],
#         [  6,   1,   2],
#         [  6,   1,   2],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (433, 462, 3)

# %%
grayscale_image = cv2.cvtColor(img,cv2.COLOR_BGR2YCrCb)

# %%
grayscale_image
# Out:
# array([[[  2, 128, 130],
#         [  2, 128, 130],
#         [  2, 128, 130],
#         ...,
#         [206, 152,  65],
#         [217, 151,  67],
#         [212, 148,  75]],
#
#        [[  2, 128, 130],
#         [  2, 128, 130],
#         [  2, 128, 130],
#         ...,
#         [211, 151,  66],
#         [214, 150,  67],
#         [219, 149,  73]],
#
#        [[  2, 128, 130],
#         [  2, 128, 130],
#         [  2, 128, 130],
#         ...,
#         [231, 145,  73],
#         [218, 149,  71],
#         [222, 148,  71]],
#
#        ...,
#
#        [[  2, 128, 130],
#         [  2, 128, 130],
#         [  2, 128, 130],
#         ...,
#         [ 24, 130, 141],
#         [ 24, 130, 141],
#         [ 24, 130, 141]],
#
#        [[  2, 128, 130],
#         [  2, 128, 130],
#         [  2, 128, 130],
#         ...,
#         [ 24, 130, 141],
#         [ 24, 130, 141],
#         [ 24, 130, 141]],
#
#        [[  2, 128, 130],
#         [  2, 128, 130],
#         [  2, 128, 130],
# ...

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (433, 462, 3)

# %%
plt.imshow(grayscale_image)
plt.axis('off')
plt.show()

# %%
grayscale_image = cv2.imread("C:/Users/ABHISHEK/Pictures/Screenshots/Screenshot 2023-08-01 193508.png", cv2.COLOR_BGR2Lab)
grayscale_image
# Out:
# array([[[  6,   1,   2, 255],
#         [  6,   1,   2, 255],
#         [  6,   1,   2, 255],
#         ...,
#         [101, 210, 235, 255],
#         [139, 227, 250, 255],
#         [115, 224, 248, 255]],
#
#        [[  6,   1,   2, 255],
#         [  6,   1,   2, 255],
#         [  6,   1,   2, 255],
#         ...,
#         [150, 223, 248, 255],
#         [156, 229, 250, 255],
#         [160, 231, 250, 255]],
#
#        [[  6,   1,   2, 255],
#         [  6,   1,   2, 255],
#         [  6,   1,   2, 255],
#         ...,
#         [116, 219, 248, 255],
#         [126, 221, 247, 255],
#         [164, 235, 254, 255]],
#
#        ...,
#
#        [[154,  81,  63, 255],
#         [152,  89,  69, 255],
#         [148,  95,  61, 255],
#         ...,
#         [ 47,  18,  27, 255],
#         [ 47,  18,  27, 255],
#         [ 47,  18,  27, 255]],
#
#        [[  6,   3,   2, 255],
#         [  9,   2,   2, 255],
#         [ 12,   1,   3, 255],
#         ...,
#         [ 47,  18,  27, 255],
# ...
